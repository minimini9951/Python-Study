# %% [markdown]
# # 4. 그래프 그리기

# %%
import seaborn as sns

# %% [markdown]
# ## 앤스콤 데이터 집합 불러오기

# %%
anscombe = sns.load_dataset('anscombe')
print(anscombe)
print(type(anscombe))
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %% [markdown]
# ### matplotlib 라이브러리 불러오기

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt #  라이브러리 불러오기

# %%
dataset_1 = anscombe[anscombe['dataset'] == 'I'] #  데이터 값이 'I'인 것만 추출

# %% [markdown]
# #### 선 그래프 그리기

# %%
plt.plot(dataset_1['x'], dataset_1['y'])
plt.show()

# %%
plt.plot(dataset_1['x'], dataset_1['y'], 'o')
plt.show()

# %% [markdown]
# ### 앤스콤 데이터 집합 모두 사용해 그래프 만들기

# %% [markdown]
# ### mathplotlib 라이브러리로 그래프 그리는 순서
# - 1. 전체 그래프가 위치할 기본 틀 만들기
# - 2. 그래프를 그려 넣을 그래프 격자 만들기
# - 3. 격자에 그래프를 하나씩 추가 : 그래프는 왼쪽에서 오른쪽으로 추가됨
# - 4. 격자가 꽉차면 다음 행에 그래프를 그려넣음

# %% [markdown]
# #### 한 번에 4개의 그래프 그리기

# %%
# 데이터를 불린형으로 추출하여 데이터셋에 저장
dataset_2 = anscombe[anscombe['dataset'] == 'II']
dataset_3 = anscombe[anscombe['dataset'] == 'III']
dataset_4 = anscombe[anscombe['dataset'] == 'IV']

# %% [markdown]
# ##### 그래프 격자가 위치할 기본 틀 : figure()

# %%
fig = plt.figure()

# %% [markdown]
# ##### 그래프 격자 그리기 : add_subplot()

# %%
fig = plt.figure()
axis1 = fig.add_subplot(2, 2, 1)
axis2 = fig.add_subplot(2, 2, 2)
axis3 = fig.add_subplot(2, 2, 3)
axis4 = fig.add_subplot(2, 2, 4)

# %% [markdown]
# ##### 그래프 그리기 : plot(x, y)

# %%
axis1.plot(dataset_1['x'], dataset_1['y'], 'o')
axis2.plot(dataset_2['x'], dataset_2['y'], 'o')
axis3.plot(dataset_3['x'], dataset_3['y'], 'o')
axis4.plot(dataset_4['x'], dataset_4['y'], 'o')

fig

# %% [markdown]
# ##### 그래프 격자에 제목 추가 : set_title

# %%
axis1.set_title('dataset_1')
axis2.set_title('dataset_2')
axis3.set_title('dataset_3')
axis4.set_title('dataset_4')

fig

# %% [markdown]
# ##### 기본 틀 제목 추가 : suptitle()

# %%
fig.suptitle('Anscombe Data')
fig

# %% [markdown]
# ##### 그래프 겹치는 부분 해결 : tight_layout()

# %%
fig.tight_layout()
fig

# %% [markdown]
# ## 기초 그래프 그리기 : 히스토그램, 산점도, 박스
# - 히스토그램 : 데이터 분포와 빈도를 살펴보는 용도

# %% [markdown]
# ### tips 데이터셋 불러와서 저장

# %%
tips = sns.load_dataset('tips')
print(tips.head())
print(type(tips))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ### 히스토그램 그리기

# %% [markdown]
# #### 기본 틀 생성

# %%
fig = plt.figure()
axes1 = fig.add_subplot(1, 1, 1)

# %% [markdown]
# #### 히스토그램 그리기 : hist()

# %%
axes1.hist(tips['total_bill'], bins=10)
axes1.set_title('Histogram of Total Bill')
axes1.set_xlabel('Frequency')
axes1.set_ylabel('Total Bill')

fig

# %% [markdown]
# ### 산점도 그래프 : scatter()

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1, 1, 1)
axes1.scatter(tips['total_bill'], tips['tip'])
axes1.set_title('Scatterplot of Total Bill vs Tip')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# ### 박스 그래프 : boxplot()

# %%
boxplot = plt.figure()
axes1 = boxplot.add_subplot(1, 1, 1)

axes1.boxplot([tips[tips['sex'] == 'Female']['tip'],
              tips[tips['sex'] == 'Male']['tip']],
              labels=['Female', 'Male'])

axes1.set_xlabel('Sex')
axes1.set_ylabel('Tip')
axes1.set_title('Boxplot of Tips by Sex')
# Out:
# Text(0.5, 1.0, 'Boxplot of Tips by Sex')

# %% [markdown]
# ## 다변량 그래프
# - 3개이상의 변수를 사용한 그래프

# %% [markdown]
# ### 산점도 그래프 : 성별 변수추가(색상으로 구분)

# %%
# 성별을 1과 0으로 구분하는 함수 생성
def record_s(s):
    if s == 'Female':
        return 0
    else:
        return 1

# %%
# 색상으로 구분하기위해 0과 1로 구분된 열 추가
tips['sex_color'] = tips['sex'].apply(record_s)

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1, 1, 1)
axes1.scatter(
    x=tips['total_bill'],
    y=tips['tip'],
    s=tips['size'] * 10,
    c=tips['sex_color'],
    alpha=0.5)
axes1.set_title('Total Bill vs Tip Colored by Sex and Sized by Size')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# ## Seaborn 라이브러리 사용
# - subplots() : figure 와 axes 값을 받음.
# - figure : 전체 subplot(서브플로안에 몇개의 그래프가 있던지 상관없이  그걸 담는 하나)
# - axes : 전체 내부의 갯수(서브플롯 안에 2개(a1,a2)의 그래프가 있다면 a1, a2)

# %% [markdown]
# ### 바이올린 그래프 : violinplot() - 색상추가 : (hue = 'x')
# - hue : 색상을 다르게 하고싶은 변수이름을 지정

# %%
ax = plt.subplots()
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)

# %% [markdown]
# ### 산점도, 관계 그래프 그리기
# - 색상 추가 : 메서드에 hue 인잣값에 색상에 사용할 열 이름 추가

# %%
scatter = sns.lmplot(x='total_bill', y='tip', data=tips,
                     hue='sex', fit_reg=False)
fig = sns.pairplot(tips, hue='sex')

# %% [markdown]
# #### 크기와 모양, 기호 조절 - 안됨, 선생님한테 물어볼 것
# - scatter_kws 에 딕셔너리 형태로 인잣값을 전달

# %%
# scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False,
#                      hue='sex', markers=['o', 'x'],
#                      scatter_kws={'s': tips['size']*10})

# %% [markdown]
# ### 4개의 데이터 그룹 그래프 한번에 나타내기 : lmplot()
# - col, col_warp 인자를 설정
# - fig_reg 인자는 회귀선의 유무를 나타냄

# %%
anscombe_plot = sns.lmplot(x='x', y='y', data=anscombe, fit_reg=False,
                           col='dataset', col_wrap=2)

# %% [markdown]
# #### 번외1. FacetGrid 클래스로 그래프 그리기
# - FacetGrid에 데이터프레임과 열이름을 전달하여 객체 생성
# - 객체의 map 메서드에 그래프의 종류와 x축으로 지정할 열이름을 순서대로 전달

# %%
# FacetGrid에 데이터프레임과 열이름을 전달하여 객체 생성
facet = sns.FacetGrid(tips, col='time')
# 객체의 map 메서드에 그래프의 종류와 x축으로 지정할 열이름을 순서대로 전달
facet.map(sns.histplot, 'total_bill', kde=True)

# %% [markdown]
# #### 번외2. 다변량 그래프 그리기

# %%
facet = sns.FacetGrid(tips, col='day', hue='sex')
facet = facet.map(plt.scatter, 'total_bill', 'tip')
facet = facet.add_legend()

# %% [markdown]
# #### 번외3. 더 많은 변수사용

# %%
facet = sns.FacetGrid(tips, col='time', row='smoker', hue='sex')
facet.map(plt.scatter, 'total_bill', 'tip')

# %% [markdown]
# ## 단변량 그래프

# %% [markdown]
# ### 히스토그램

# %%
import seaborn as sns
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
ax = plt.subplots()
ax = sns.histplot(tips['total_bill'], kde=True)
ax.set_title('Total Bill Histogram')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
ax = plt.subplots()
ax = sns.countplot('day', data=tips)
ax.set_title('Count of Days')
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### 산점도 그래프 : scatter()

# %% [markdown]
# #### 회귀선 함께 출력 : regplot()

# %%
ax = plt.subplots()
ax = sns.regplot(x='total_bill', y='tip', data=tips)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
ax = plt.subplots()
ax = sns.regplot(x='total_bill', y='tip', data=tips, fit_reg=False)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# #### 히스토그램 함께 출력 : jointplot()

# %%
joint = sns.jointplot(x='total_bill', y='tip', data=tips)
joint.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
joint.fig.suptitle('Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# Text(0.5, 1.03, 'Joint Plot of Total Bill and Tip')

# %% [markdown]
# #### 육각그래프 : hexbim(jointplot과 형식 동일, kind='hex' 지정해주면 변경됨)

# %%
hexbin = sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex')
hexbin.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
hexbin.fig.suptitle('Hexbin Joint Plot of Total Bill and Tip',
                    fontsize=10, y=1.03)
# Out:
# Text(0.5, 1.03, 'Hexbin Joint Plot of Total Bill and Tip')

# %% [markdown]
# #### 이차원 밀집도 그래프 : kdeplot()

# %%
ax = plt.subplots()
ax = sns.kdeplot(x=tips['total_bill'],
                y=tips['tip'],
                shade=True)
ax.set_title('Kernel Density Plot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
ax = plt.subplots()
ax = sns.barplot(x='time', y='total_bill', data=tips)
ax.set_title('Bar plot of average total bill for time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Average total bill')
# Out:
# Text(0, 0.5, 'Average total bill')

# %% [markdown]
# ### 박스 그래프 : boxplot()

# %%
ax = plt.subplots() # 격자 생성
ax = sns.boxplot(x='time', y='total_bill', data=tips)
ax.set_title('Boxplot of total bill by time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %% [markdown]
# #### 바이올린 그래프 : violinplot()
# - 박스 그래프에서 데이터 분산이 모호하게 표현될 때 사용

# %%
ax = plt.subplot()
ax = sns.violinplot(x='time', y='total_bill', data=tips)
ax.set_title('Violin plot of total bill by time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %% [markdown]
# ### 관계 그래프 : pairplot
# - 중복된 그래프가 출력되기 때문에 원하는 그래프로 교체 해줘야함

# %%
fig = sns.pairplot(tips)

# %%
pair_grid = sns.PairGrid(tips)
pair_gird = pair_grid.map_upper(sns.regplot)
pair_grid = pair_grid.map_lower(sns.kdeplot, shade=True)
pair_grid = pair_grid.map_diag(sns.histplot, kde=True)
plt.show()

# %% [markdown]
# ## 데이터프레임과 시리즈로 그래프 나타내기
# - 밀집도, 산점도, 육각 그래프는 각각 kde, scatter, hexbin 메서드 사용

# %% [markdown]
# ### 히스토그램 : plot.hist()
# - 투명도를 조절하려면 alpha, bins, ax 인자를 사용

# %%
ax = plt.subplot()
ax = tips['total_bill'].plot.hist()

# %%
fig, ax = plt.subplots()
# alpha : 투명도, bins : x축간격
ax = tips[['total_bill', 'tip']].plot.hist(alpha=0.5, bins=20, ax=ax)

# %% [markdown]
# ### 밀집도 그래프 : plot.kde()

# %%
ax = plt.subplots()
ax = tips['tip'].plot.kde()

# %% [markdown]
# ### 산점도 그래프 : plot.scatter()

# %%
fig, ax = plt.subplots()
ax = tips.plot.scatter(x='total_bill', y='tip', ax=ax)

# %% [markdown]
# ### 육각 그래프 : plot.hexbin()

# %%
fig, ax = plt.subplots()
# 육각형 크기는 gridsize 사용 : 값이 작아지면 커짐
ax = tips.plot.hexbin(x='total_bill', y='tip', gridsize=25, ax=ax, title='total bill')

# %% [markdown]
# ### 박스 그래프 : plot.box()

# %%
fig, ax = plt.subplots()
ax = tips.plot.box(ax=ax)

# %% [markdown]
# ## seaborn 라이브러리로 그래프 스타일 지정 : set_style()
# - 스타일을 적용할 부분에서 한번만 실행

# %%
sns.set_style('whitegrid')
fig, ax = plt.subplots()
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)

# %%
# 모든 스타일을 하나씩 적용
fig = plt.figure()
seaborn_styles = ['darkgrid', 'whitegrid', 'dark', 'white', 'ticks']

for idx, style in enumerate(seaborn_styles):
    plot_position = idx + 1
    with sns.axes_style(style):
        ax = fig.add_subplot(2, 3, plot_position)
        violin = sns.violinplot(x='time', y='total_bill', data=tips, ax=ax)
        violin.set_title(style)

fig.tight_layout()
